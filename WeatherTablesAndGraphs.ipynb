# %%
import pandas as pd
import plotly.express as px
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets

# %%
#Import csv
csv_path = "Resources/cities.csv"
df = pd.read_csv(csv_path)
df = df.set_index('City_ID')
df.head(10)
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0        jacareacanga           0      BR  1528902000        62  -6.22
# 1          kaitangata         100      NZ  1528905304        94 -46.28
# 2            goulburn          20      AU  1528905078        91 -34.75
# 3                lata          76      IN  1528905305        89  30.78
# 4          chokurdakh           0      RU  1528905306        88  70.62
# 5            martyush          92      RU  1528905306        94  56.40
# 6              hobart          20      AU  1528902000        87 -42.88
# 7         broken hill           0      AU  1528905311        88 -31.97
# 8           harnosand           0      SE  1528903200        44  62.63
# 9           tuatapere           0      NZ  1528905312       100 -46.13
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0        -57.76     89.60        6.93
# 1        169.85     42.61        5.64
# 2        149.72     44.32       10.11
# ...

# %%
#Table
#Convert csv to html
cities_HTML= df.to_html(buf=None, 
                        columns=None, 
                        col_space=None, 
                        header=True, 
                        index=True, 
                        na_rep='NaN', 
                        formatters=None, 
                        float_format=None, 
                        sparsify=None, 
                        index_names=False, 
                        justify=None, 
                        bold_rows=True, 
                        classes=None, 
                        escape=True, 
                        max_rows=None, 
                        max_cols=None, 
                        show_dimensions=False, 
                        notebook=False)
# print(cities_HTML)

# %%
#Table
# write html to file 
text_file = open("cities_index1.html", "w") 
x=text_file.write(cities_HTML) 
text_file.close()

# %%
#Scatter plot 1: Lattitude vs. Max Temperature(F) 
x_values = df['Lat']
y_values = df['Max Temp']
temp=plt.scatter(x_values,y_values)
plt.xlabel('Lattitude')
plt.ylabel('Max Temperature(F)')
plt.title('City Lattitude vs. Max Temperature(F) (01/05/17)')

plt.show()

# %%
#save scatter?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-f1eb7d25c96d> in <module>
#       1 #save scatter?
# ----> 2 temp.write_html("visualizations/temp.html")
#
# AttributeError: 'PathCollection' object has no attribute 'write_html'

# %%
#Scatter plot 2: Lattitude vs. Humidity(%)
x_values = df['Lat']
y_values = df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Lattitude')
plt.ylabel('Humidity(%)')
plt.title('City Lattitude vs. Humidity(%) (01/05/17)')
plt.show()

# %%
#save scatter?

# %%
#Scatter plot 3: Lattitude vs. Cloudiness
x_values = df['Lat']
y_values = df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness')
plt.title('City Lattitude vs. Cloudiness (01/05/17)')
plt.show()

# %%
#save scatter?

# %%
#Scatter plot 4: Lattitude vs. Wind Speed
x_values = df['Lat']
y_values = df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed')
plt.title('City Lattitude vs. Wind Speed (01/05/17)')
plt.show()

# %%
#save scatter?
